# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

DATA_PATH = 'book_meta.parquet'
df_books = pd.read_parquet(DATA_PATH)

# %%
df_books.head()
# Out:
#     book_id author_id                                              title  \
# 0   6474616   2802356                           تان تان والبحيرة الغامضة
# 1    445501      8164                   Alice's Adventures in Wonderland
# 2    445503    250484  Taught by America: A Story of Struggle and Hop...
# 3  11007713   4767184  Learning iPad Programming: A Hands-On Guide to...
# 4  12636575   1385066                                  A Rapariga Errada
#
#                                               genres  \
# 0               [comics, graphic, fiction, children]
# 1           [children, fantasy, paranormal, fiction]
# 2  [non-fiction, history, historical fiction, bio...
# 3                                      [non-fiction]
# 4                                                 []
#
#                                          description
# 0  A Tintin Film Book\nTintin, Snowy and Captain ...
# 1  Purchase one of 1st World Library's Classic Bo...
# 2  After graduating from Yale University, Sarah S...
# 3  "Learning iPad Programming" walks you through ...
# 4  O novo livro de Pedro Paixao trata de uma curi...
